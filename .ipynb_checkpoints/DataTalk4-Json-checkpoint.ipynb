# %%
# HOW TO HANDLE JSON DATA
import pandas as pd
import json
import parse_json

# %%
# Open json data
with open("Leagues of Legends/champion_info_2.json", "r+") as f:
    json_data = json.load(f)
champion = pd.DataFrame(json_data)
champion.reset_index(inplace=True)
champion.rename(columns={"index": "name"}, inplace=True)
champion.head()
# Out:
#       name      type version  \
# 0   Aatrox  champion  7.18.1
# 1     Ahri  champion  7.18.1
# 2    Akali  champion  7.18.1
# 3  Alistar  champion  7.18.1
# 4    Amumu  champion  7.18.1
#
#                                                 data
# 0  {'tags': ['Fighter', 'Tank'], 'title': 'the Da...
# 1  {'tags': ['Mage', 'Assassin'], 'title': 'the N...
# 2  {'tags': ['Assassin'], 'title': 'the Fist of S...
# 3  {'tags': ['Tank', 'Support'], 'title': 'the Mi...
# 4  {'tags': ['Tank', 'Mage'], 'title': 'the Sad M...

# %%
# Convert the json data to DataFrame
first_row_data = champion.data[0]
champ_data = pd.DataFrame(first_row_data)
for i in range(1, champion.shape[0]):
    champ_data = champ_data.append(pd.DataFrame(champion.data[i]))
champ_data = pd.DataFrame(champ_data.groupby(['title', 'id', 'name', 'key'])['tags'].apply(lambda x: "%s" % ', '.join(x)))
champ_data.reset_index(inplace=True)
champ_merge = pd.merge(champion, champ_data, how="left", on="name")
champ_merge.head()
# Out:
#       name      type version  \
# 0   Aatrox  champion  7.18.1
# 1     Ahri  champion  7.18.1
# 2    Akali  champion  7.18.1
# 3  Alistar  champion  7.18.1
# 4    Amumu  champion  7.18.1
#
#                                                 data                title  \
# 0  {'tags': ['Fighter', 'Tank'], 'title': 'the Da...     the Darkin Blade
# 1  {'tags': ['Mage', 'Assassin'], 'title': 'the N...  the Nine-Tailed Fox
# 2  {'tags': ['Assassin'], 'title': 'the Fist of S...   the Fist of Shadow
# 3  {'tags': ['Tank', 'Support'], 'title': 'the Mi...         the Minotaur
# 4  {'tags': ['Tank', 'Mage'], 'title': 'the Sad M...        the Sad Mummy
#
#       id      key            tags
# 0  266.0   Aatrox   Fighter, Tank
# 1  103.0     Ahri  Mage, Assassin
# 2   84.0    Akali        Assassin
# 3   12.0  Alistar   Tank, Support
# 4   32.0    Amumu      Tank, Mage

# %%
# General method to parse json and add data to the dataframe
champion = parse_json.parse_json(champion, 'data')
champion.head()
# Out:
#       name      type version  \
# 0   Aatrox  champion  7.18.1
# 1     Ahri  champion  7.18.1
# 2    Akali  champion  7.18.1
# 3  Alistar  champion  7.18.1
# 4    Amumu  champion  7.18.1
#
#                                                 data              tags  \
# 0  {'tags': ['Fighter', 'Tank'], 'title': 'the Da...   [Fighter, Tank]
# 1  {'tags': ['Mage', 'Assassin'], 'title': 'the N...  [Mage, Assassin]
# 2  {'tags': ['Assassin'], 'title': 'the Fist of S...        [Assassin]
# 3  {'tags': ['Tank', 'Support'], 'title': 'the Mi...   [Tank, Support]
# 4  {'tags': ['Tank', 'Mage'], 'title': 'the Sad M...      [Tank, Mage]
#
#        key   id                title
# 0   Aatrox  266     the Darkin Blade
# 1     Ahri  103  the Nine-Tailed Fox
# 2    Akali   84   the Fist of Shadow
# 3  Alistar   12         the Minotaur
# 4    Amumu   32        the Sad Mummy
